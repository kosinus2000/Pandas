# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
bar = pd.read_csv(r"C:\Users\huber_15ivafg\Documents\Pandas kurs materiały\course-files\weather_barcelona.csv", index_col='Date')

# %%
rom = pd.read_csv(r"C:\Users\huber_15ivafg\Documents\Pandas kurs materiały\course-files\weather_rome.csv", index_col='Date')

# %%
ams = pd.read_csv(r"C:\Users\huber_15ivafg\Documents\Pandas kurs materiały\course-files\weather_amsterdam.csv", index_col='Date')

# %%
bar.head()
# Out:
#             TempMax  TempMin  Rain  AvgTempMax  AvgTempMin
# Date
# 2018-01-01       17       11     0          13           7
# 2018-01-02       19        8     0          13           7
# 2018-01-03       23       11     0          13           7
# 2018-01-04       24       15     0          13           7
# 2018-01-05       20       10     0          13           7

# %%
bar.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
bar['TempMax'].plot()
# Out:
# <Axes: xlabel='Date'>
