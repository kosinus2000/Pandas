# %%
import pandas as pd
import numpy as np
professions = pd.read_csv("C:\\Users\\huber_15ivafg\\Documents\\Pandas kurs materiały\\course-files\\Prestige.csv")
professions.head(5)
# Out:
#                   name  education  income  women  prestige  census  type
# 0   gov.administrators      13.11   12351  11.16      68.8    1113  prof
# 1     general.managers      12.26   25879   4.02      69.1    1130  prof
# 2          accountants      12.77    9271  15.70      63.4    1171  prof
# 3  purchasing.officers      11.42    8865   9.11      56.8    1175  prof
# 4             chemists      14.62    8403  11.68      73.5    2111  prof

# %%
dict = {
    'name':'[data scientist]',
    'education':[np.nan],
    'income':[np.nan],
    'women':[np.nan],
    'prestige':[np.nan],
    'census':[np.nan],
    'type':[np.nan]}
dict
# Out:
# {'name': '[data scientist]',
#  'education': [nan],
#  'income': [nan],
#  'women': [nan],
#  'prestige': [nan],
#  'census': [nan],
#  'type': [nan]}

# %%
pd.concat([professions,pd.DataFrame(dict)], ignore_index=True)
# Out:
#                     name  education   income  women  prestige  census  type
# 0     gov.administrators      13.11  12351.0  11.16      68.8  1113.0  prof
# 1       general.managers      12.26  25879.0   4.02      69.1  1130.0  prof
# 2            accountants      12.77   9271.0  15.70      63.4  1171.0  prof
# 3    purchasing.officers      11.42   8865.0   9.11      56.8  1175.0  prof
# 4               chemists      14.62   8403.0  11.68      73.5  2111.0  prof
# ..                   ...        ...      ...    ...       ...     ...   ...
# 98          taxi.drivers       7.93   4224.0   3.59      25.1  9173.0    bc
# 99          longshoremen       8.37   4753.0   0.00      26.1  9313.0    bc
# 100          typesetters      10.00   6462.0  13.58      42.2  9511.0    bc
# 101          bookbinders       8.55   3617.0  70.87      35.2  9517.0    bc
# 102     [data scientist]        NaN      NaN    NaN       NaN     NaN   NaN
#
# [103 rows x 7 columns]

# %%
taxi = professions[professions["name"]=='taxi.drivers']
taxi
# Out:
#             name  education  income  women  prestige  census type
# 98  taxi.drivers       7.93    4224   3.59      25.1    9173   bc

# %%
professions.drop(98,inplace=True)
professions.tail()
# Out:
#                 name  education  income  women  prestige  census type
# 96   train.engineers       8.49    8845   0.00      48.9    9131   bc
# 97       bus.drivers       7.58    5562   9.47      35.9    9171   bc
# 99      longshoremen       8.37    4753   0.00      26.1    9313   bc
# 100      typesetters      10.00    6462  13.58      42.2    9511   bc
# 101      bookbinders       8.55    3617  70.87      35.2    9517   bc

# %%
professions = pd.concat([professions,taxi])
professions.tail()
# Out:
#              name  education  income  women  prestige  census type
# 97    bus.drivers       7.58    5562   9.47      35.9    9171   bc
# 99   longshoremen       8.37    4753   0.00      26.1    9313   bc
# 100   typesetters      10.00    6462  13.58      42.2    9511   bc
# 101   bookbinders       8.55    3617  70.87      35.2    9517   bc
# 98   taxi.drivers       7.93    4224   3.59      25.1    9173   bc

# %%
del professions ['census']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\PycharmProjects\Pandas\.venv\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'census'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 del professions ['census']
#
# ...

# %%
professions.tail()
# Out:
#              name  education  income  women  prestige type
# 97    bus.drivers       7.58    5562   9.47      35.9   bc
# 99   longshoremen       8.37    4753   0.00      26.1   bc
# 100   typesetters      10.00    6462  13.58      42.2   bc
# 101   bookbinders       8.55    3617  70.87      35.2   bc
# 98   taxi.drivers       7.93    4224   3.59      25.1   bc

# %%
professions.drop(axis=1, columns=['type'], inplace=True)

# %%
professions.tail()
# Out:
#              name  education  income  women  prestige
# 97    bus.drivers       7.58    5562   9.47      35.9
# 99   longshoremen       8.37    4753   0.00      26.1
# 100   typesetters      10.00    6462  13.58      42.2
# 101   bookbinders       8.55    3617  70.87      35.2
# 98   taxi.drivers       7.93    4224   3.59      25.1
